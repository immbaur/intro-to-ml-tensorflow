# %% [markdown]
# # Inference and Validation
#
# Now that you have a trained network, you can use it for making predictions. This is typically called **inference**, a term borrowed from statistics. However, neural networks have a tendency to perform *too well* on the training data and aren't able to generalize to data that hasn't been seen before. This is called **overfitting** and it impairs inference performance. To test for overfitting while training, we measure the performance on data not in the training set called the **validation** set. We avoid overfitting through regularization such as dropout while monitoring the validation performance during training.

# %% [markdown]
# ## Import Resources

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import numpy as np
import matplotlib.pyplot as plt

import tensorflow as tf
import tensorflow_datasets as tfds
tfds.disable_progress_bar()

# %%
import logging
logger = tf.get_logger()
logger.setLevel(logging.ERROR)

# %%
print('Using:')
print('\t\u2022 TensorFlow version:', tf.__version__)
print('\t\u2022 tf.keras version:', tf.keras.__version__)
print('\t\u2022 Running on GPU' if tf.test.is_gpu_available() else '\t\u2022 GPU device not found. Running on CPU')
# Out:
# Using:
# 	• TensorFlow version: 2.3.0
# 	• tf.keras version: 2.4.0
# 	• GPU device not found. Running on CPU

# %% [markdown]
# ## Load the Dataset
#
# We are now going to load the Fashion-MNIST dataset using tensorflow_datasets as we've done before. In this case, however, we are going to define how to split the dataset ourselves. We are going to split the dataset such that 60\% of the data will be used for training, 20\% of the data will be used for validation, and the remaining 20\% of the data will be used for testing.
#
# To do this, we are going to do two things in succession. First we are going to combine (merge) the `train` and `test` splits. After the splits are merged into a single set, we are going to sub-split it into three sets, where the first set has 60\% of the data, the second set has 20\% of the data, and the third set has the remaining 20\% of the data.
#
# To merge all the splits of a dataset together, we can use `split=tfds.Split.ALL`. For example,
#
# ```python
# dataset = tfds.load('fashion_mnist', split=tfds.Split.ALL)
# ```
#
# will return a `dataset` that contains a single set with 70,000 examples. This is because the Fashion-MNIST dataset has a `train` split with 60,000 examples and a `test` split with 10,000 examples. The `tfds.Split.ALL` keyword merged both splits into a single set containing the combined data from both splits.
#
# After we have merged the splits into a single set, we need to sub-split it. We can sub-split our dataset by using the `.subsplit()` method. There are various ways in which we can use the `.subsplit()` method. Here we are going to sub-split the data by providing the percentage of data we want in each set. To do this we just pass a list with percentages we want in each set. For example,
#
# ```python
# split=tfds.Split.ALL.subsplit([60,20,20])
# ```
#
# will sub-split our dataset into three sets, where the first set has 60\% of the data, the second set has 20\% of the data, and the third set has the remaining 20\% of the data. A word of **caution**, TensorFlow Datasets does not guarantee the reproducibility of the sub-split operations. That means, that two different users working on the same version of a dataset and using the same sub-split operations could end-up with two different sets of examples. Also, if a user regenerates the data, the sub-splits may no longer be the same. To learn more about `subsplit` and other ways to sub-split your data visit the [Split Documentation](https://www.tensorflow.org/datasets/splits#subsplit).

# %%
train_split = 60
test_val_split = 20


# splits = tfds.Split.ALL.subsplit([train_split, test_val_split, test_val_split])
# dataset, dataset_info = tfds.load('fashion_mnist', split=splits, as_supervised=True, with_info=True)
# training_set, validation_set, test_set = dataset

training_set = tfds.load('fashion_mnist', split='train[:80%]', as_supervised=True)
validation_set = tfds.load('fashion_mnist', split='train[-20%:]', as_supervised=True)
test_set = tfds.load('fashion_mnist', split='test', as_supervised=True)

num_training_examples = len(list(training_set))
num_validation_examples = len(list(validation_set))
num_test_examples = len(list(test_set))

print(num_training_examples)
print(num_validation_examples)
print(num_test_examples)
# Out:
# 48000
# 12000
# 10000

# %% [markdown]
# When we use `split=tfds.Split.ALL.subsplit([60,20,20])`, `tensorflow_datasets` returns a tuple with our sub-splits. Since we divided our dataset into 3 sets, then, in this case, `dataset` should be a tuple with 3 elements.

# %%
# Check that dataset is a tuple
print('dataset has type:', type(dataset))

# Print the number of elements in dataset
print('dataset has {:,} elements '.format(len(dataset)))
# Out:
# dataset has type: <class 'list'>
# dataset has type: <class 'list'>

# %%
# Display dataset
dataset

# %%
# Display dataset_info
dataset_info

# %% [markdown]
# ## Explore the Dataset

# %%
total_examples = dataset_info.splits['train'].num_examples + dataset_info.splits['test'].num_examples

num_training_examples = (total_examples * train_split) // 100
num_validation_examples = (total_examples * test_val_split) // 100
num_test_examples = num_validation_examples

print('There are {:,} images in the training set'.format(num_training_examples))
print('There are {:,} images in the validation set'.format(num_validation_examples))
print('There are {:,} images in the test set'.format(num_test_examples))

# %%
class_names = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat', 
               'Sandal',      'Shirt',   'Sneaker',  'Bag',   'Ankle boot']

# %% [markdown]
# ## Create Pipeline

# %%
def normalize(image, label):
    image = tf.cast(image, tf.float32)
    image /= 255
    return image, label

batch_size = 64

training_batches = training_set.cache().shuffle(num_training_examples//4).batch(batch_size).map(normalize).prefetch(1)
validation_batches = validation_set.cache().batch(batch_size).map(normalize).prefetch(1)
testing_batches = test_set.cache().batch(batch_size).map(normalize).prefetch(1)

# %% [markdown]
# ## Build the Model
#
# Here we'll build and compile our model as usual.

# %%
model = tf.keras.Sequential([
        tf.keras.layers.Flatten(input_shape=(28,28,1)),
        tf.keras.layers.Dense(256, activation = 'relu'),
        tf.keras.layers.Dense(128, activation = 'relu'),
        tf.keras.layers.Dense(64, activation = 'relu'),
        tf.keras.layers.Dense(10, activation = 'softmax')
])

# %%
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %% [markdown]
# ## Evaluate Loss and Accuracy on the Test Set
#
# The goal of validation is to measure the model's performance on data that isn't part of the training set. Performance here is up to the developer to define though. Typically this is just accuracy, the percentage of classes the network predicted correctly. Other options are [precision and recall](https://en.wikipedia.org/wiki/Precision_and_recall#Definition_(classification_context)) and top-5 error rate. We'll focus on accuracy here. Let's see how the model performs on our test set.

# %%
loss, accuracy = model.evaluate(testing_batches)

print('\nLoss on the TEST Set: {:,.3f}'.format(loss))
print('Accuracy on the TEST Set: {:.3%}'.format(accuracy))
# Out:
# 157/157 [==============================] - 0s 1ms/step - loss: 2.4418 - accuracy: 0.0998
#
# Loss on the TEST Set: 2.442
# Accuracy on the TEST Set: 9.980%

# %% [markdown]
# The network is untrained so it's making random guesses and we should see an accuracy around 10%.

# %% [markdown]
# ## Train the Model with the Validation Set
#
# Now let's train our network as usual, but this time we are also going to incorporate our validation set into the training process.
#
# During training, the model will only use the training set in order to decide how to modify its weights and biases. Then, after every training epoch we calculate the loss on the training and validation sets. These metrics tell us how well our model is "learning" because it they show how well the model generalizes to data that is not used for training. It's important to remember that the model does not use any part of the validation set to tune its weights and biases, therefore it can tell us if we're overfitting the training set.
#
# We can incorporate our validation set into the training process by including the `validation_data=validation_batches` argument in the `.fit` method.

# %%
EPOCHS = 30

history = model.fit(training_batches,
                    epochs = EPOCHS,
                    validation_data=validation_batches)
# Out:
# Epoch 1/30
# 750/750 [==============================] - 2s 2ms/step - loss: 0.5196 - accuracy: 0.8148 - val_loss: 0.4013 - val_accuracy: 0.8533
# Epoch 2/30
# 750/750 [==============================] - 2s 2ms/step - loss: 0.3821 - accuracy: 0.8598 - val_loss: 0.3614 - val_accuracy: 0.8626
# Epoch 3/30
# 750/750 [==============================] - 2s 2ms/step - loss: 0.3422 - accuracy: 0.8736 - val_loss: 0.3416 - val_accuracy: 0.8769
# Epoch 4/30
# 750/750 [==============================] - 1s 2ms/step - loss: 0.3150 - accuracy: 0.8842 - val_loss: 0.3359 - val_accuracy: 0.8736
# Epoch 5/30
# 750/750 [==============================] - 2s 2ms/step - loss: 0.3010 - accuracy: 0.8872 - val_loss: 0.3347 - val_accuracy: 0.8773
# Epoch 6/30
# 750/750 [==============================] - 2s 2ms/step - loss: 0.2825 - accuracy: 0.8934 - val_loss: 0.2969 - val_accuracy: 0.8917
# Epoch 7/30
# 750/750 [==============================] - 2s 2ms/step - loss: 0.2706 - accuracy: 0.8978 - val_loss: 0.3030 - val_accuracy: 0.8907
# Epoch 8/30
# 750/750 [==============================] - 2s 2ms/step - loss: 0.2548 - accuracy: 0.9043 - val_loss: 0.3106 - val_accuracy: 0.8884
# Epoch 9/30
# 750/750 [==============================] - 2s 2ms/step - loss: 0.2474 - accuracy: 0.9063 - val_loss: 0.2999 - val_accuracy: 0.8928
# Epoch 10/30
# 750/750 [==============================] - 1s 2ms/step - loss: 0.2373 - accuracy: 0.9106 - val_loss: 0.3135 - val_accuracy: 0.8918
# Epoch 11/30
# 750/750 [==============================] - 2s 2ms/step - loss: 0.2279 - accuracy: 0.9139 - val_loss: 0.3044 - val_accuracy: 0.8918
# Epoch 12/30
# 750/750 [==============================] - 2s 2ms/step - loss: 0.2191 - accuracy: 0.9180 - val_loss: 0.2982 - val_accuracy: 0.8997
# Epoch 13/30
# 750/750 [==============================] - 2s 2ms/step - loss: 0.2143 - accuracy: 0.9191 - val_loss: 0.3049 - val_accuracy: 0.8937
# Epoch 14/30
# 750/750 [==============================] - 2s 2ms/step - loss: 0.2031 - accuracy: 0.9229 - val_loss: 0.3058 - val_accuracy: 0.8953
# Epoch 15/30
# 750/750 [==============================] - 2s 2ms/step - loss: 0.1955 - accuracy: 0.9264 - val_loss: 0.3310 - val_accuracy: 0.8915
# Epoch 16/30
# 750/750 [==============================] - 2s 2ms/step - loss: 0.1922 - accuracy: 0.9282 - val_loss: 0.3502 - val_accuracy: 0.8840
# Epoch 17/30
# 750/750 [==============================] - 2s 2ms/step - loss: 0.1852 - accuracy: 0.9290 - val_loss: 0.3125 - val_accuracy: 0.8972
# Epoch 18/30
# 750/750 [==============================] - 2s 2ms/step - loss: 0.1843 - accuracy: 0.9300 - val_loss: 0.3058 - val_accuracy: 0.8975
# Epoch 19/30
# 750/750 [==============================] - 2s 2ms/step - loss: 0.1705 - accuracy: 0.9348 - val_loss: 0.3356 - val_accuracy: 0.8932
# Epoch 20/30
# 750/750 [==============================] - 2s 2ms/step - loss: 0.1663 - accuracy: 0.9370 - val_loss: 0.3366 - val_accuracy: 0.8972
# Epoch 21/30
# 750/750 [==============================] - 2s 2ms/step - loss: 0.1578 - accuracy: 0.9399 - val_loss: 0.3471 - val_accuracy: 0.8930
# Epoch 22/30
# 750/750 [==============================] - 2s 2ms/step - loss: 0.1560 - accuracy: 0.9405 - val_loss: 0.3600 - val_accuracy: 0.8945
# Epoch 23/30
# 750/750 [==============================] - 2s 2ms/step - loss: 0.1523 - accuracy: 0.9422 - val_loss: 0.3629 - val_accuracy: 0.8927
# Epoch 24/30
# 750/750 [==============================] - 2s 2ms/step - loss: 0.1489 - accuracy: 0.9434 - val_loss: 0.3476 - val_accuracy: 0.9003
# Epoch 25/30
# 750/750 [==============================] - 2s 2ms/step - loss: 0.1429 - accuracy: 0.9467 - val_loss: 0.3769 - val_accuracy: 0.8960
# Epoch 26/30
# 750/750 [==============================] - 2s 2ms/step - loss: 0.1372 - accuracy: 0.9473 - val_loss: 0.3724 - val_accuracy: 0.8919
# Epoch 27/30
# 750/750 [==============================] - 2s 2ms/step - loss: 0.1338 - accuracy: 0.9482 - val_loss: 0.3759 - val_accuracy: 0.8942
# Epoch 28/30
# 750/750 [==============================] - 2s 2ms/step - loss: 0.1329 - accuracy: 0.9489 - val_loss: 0.3589 - val_accuracy: 0.8931
# Epoch 29/30
# 750/750 [==============================] - 2s 2ms/step - loss: 0.1257 - accuracy: 0.9506 - val_loss: 0.4029 - val_accuracy: 0.8961
# Epoch 30/30
# 750/750 [==============================] - 2s 2ms/step - loss: 0.1211 - accuracy: 0.9532 - val_loss: 0.3778 - val_accuracy: 0.8964

# %% [markdown]
# ## Loss and Validation Plots
#
# If we look at the training and validation losses achieved on epoch 30 above, we see that the loss on the training set is much lower than that achieved on the validation set. This is a clear sign of overfitting. In other words, our model has "memorized" the training set so it performs really well on it, but when tested on data that it wasn't trained on (*i.e.* the validation dataset) it performs poorly.
#
# Let's take a look at the model's loss and accuracy values obtained during training on both the training set and the validation set. This will allow us to see how well or how bad our model is "learning". We can do this easily by using the `history` object returned by the `.fit` method. The  `history.history` attribute is a **dictionary** with a record of training accuracy and loss values at successive epochs, as well as validation accuracy and loss values when applicable.

# %%
# Check that history.history is a dictionary
print('history.history has type:', type(history.history))

# Print the keys of the history.history dictionary
print('\nThe keys of history.history are:', list(history.history.keys()))
# Out:
# history.history has type: <class 'dict'>
#
# The keys of history.history are: ['loss', 'accuracy', 'val_loss', 'val_accuracy']

# %% [markdown]
# Let's use the `history.history` dictionary to plot our model's loss and accuracy values obtained during training.

# %%
training_accuracy = history.history['accuracy']
validation_accuracy = history.history['val_accuracy']

training_loss = history.history['loss']
validation_loss = history.history['val_loss']

epochs_range=range(EPOCHS)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, training_accuracy, label='Training Accuracy')
plt.plot(epochs_range, validation_accuracy, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, training_loss, label='Training Loss')
plt.plot(epochs_range, validation_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# ## Early Stopping
#
# If we look at the training and validation losses as we train the network, we can see a phenomenon known as overfitting.
# This happens when our model performs really well on the training data but it fails to generalize well enough to also perform well on the validation set. We can tell that this is happening because when we finished training the validation loss is higher than the training loss.
#
# One way to prevent our model from overfitting is by stopping training when we achieve the lowest validation loss. If we take a look at the plots we can see that at the beginning of training the validation loss starts decreasing, then after some epochs it levels off, and then it just starts increasing. Therefore, we can stop training our model when the validation loss levels off, such that our network is accurate but it's not overfitting.
#
# This strategy is called **early-stopping**. We can implement early stopping in `tf.keras` by using a **callback**. A callback is a set of functions to be applied at given stages of the training process. You can pass a list of callbacks to the `.fit()` method by using the `callbacks` keyword argument.
#
# To implement early-stopping during training we will use the callback:
#
#
# ```python
# tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=5)
# ```
#
# The `monitor` argument specifies the quantity we want to monitor during training to determine when to stop training. The `patience` argument determines the number of consecutive epochs with no significant improvement after which training will be stopped. We can also specify the minimum change in the monitored quantity to qualify as an improvement, by specifying the `min_delta` argument. For more information on the early-stopping callback check out the [EarlyStopping
# documentation](https://www.tensorflow.org/versions/r2.0/api_docs/python/tf/keras/callbacks/EarlyStopping#class_earlystopping).

# %%
model = tf.keras.Sequential([
        tf.keras.layers.Flatten(input_shape=(28,28,1)),
        tf.keras.layers.Dense(256, activation = 'relu'),
        tf.keras.layers.Dense(128, activation = 'relu'),
        tf.keras.layers.Dense(64, activation = 'relu'),
        tf.keras.layers.Dense(10, activation = 'softmax')
])

model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# Stop training when there is no improvement in the validation loss for 5 consecutive epochs
early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=5)

history = model.fit(training_batches,
                    epochs = 100,
                    validation_data=validation_batches,
                    callbacks=[early_stopping])
# Out:
# Epoch 1/100
# 750/750 [==============================] - 2s 2ms/step - loss: 0.5231 - accuracy: 0.8149 - val_loss: 0.3869 - val_accuracy: 0.8588
# Epoch 2/100
# 750/750 [==============================] - 2s 2ms/step - loss: 0.3809 - accuracy: 0.8598 - val_loss: 0.3676 - val_accuracy: 0.8662
# Epoch 3/100
# 750/750 [==============================] - 2s 2ms/step - loss: 0.3421 - accuracy: 0.8733 - val_loss: 0.3482 - val_accuracy: 0.8746
# Epoch 4/100
# 750/750 [==============================] - 2s 2ms/step - loss: 0.3142 - accuracy: 0.8844 - val_loss: 0.3196 - val_accuracy: 0.8822
# Epoch 5/100
# 750/750 [==============================] - 2s 2ms/step - loss: 0.2959 - accuracy: 0.8908 - val_loss: 0.3129 - val_accuracy: 0.8849
# Epoch 6/100
# 750/750 [==============================] - 2s 2ms/step - loss: 0.2808 - accuracy: 0.8962 - val_loss: 0.3077 - val_accuracy: 0.8836
# Epoch 7/100
# 750/750 [==============================] - 2s 2ms/step - loss: 0.2687 - accuracy: 0.8979 - val_loss: 0.3037 - val_accuracy: 0.8912
# Epoch 8/100
# 750/750 [==============================] - 2s 2ms/step - loss: 0.2569 - accuracy: 0.9030 - val_loss: 0.2816 - val_accuracy: 0.8941
# Epoch 9/100
# 750/750 [==============================] - 2s 2ms/step - loss: 0.2435 - accuracy: 0.9089 - val_loss: 0.2963 - val_accuracy: 0.8927
# Epoch 10/100
# 750/750 [==============================] - 2s 2ms/step - loss: 0.2367 - accuracy: 0.9109 - val_loss: 0.3026 - val_accuracy: 0.8934
# Epoch 11/100
# 750/750 [==============================] - 2s 2ms/step - loss: 0.2245 - accuracy: 0.9160 - val_loss: 0.2974 - val_accuracy: 0.8925
# Epoch 12/100
# 750/750 [==============================] - 2s 2ms/step - loss: 0.2181 - accuracy: 0.9179 - val_loss: 0.2988 - val_accuracy: 0.8953
# Epoch 13/100
# 750/750 [==============================] - 2s 2ms/step - loss: 0.2080 - accuracy: 0.9207 - val_loss: 0.3014 - val_accuracy: 0.8915

# %%
training_accuracy = history.history['accuracy']
validation_accuracy = history.history['val_accuracy']

training_loss = history.history['loss']
validation_loss = history.history['val_loss']

epochs_range=range(len(training_accuracy))

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, training_accuracy, label='Training Accuracy')
plt.plot(epochs_range, validation_accuracy, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, training_loss, label='Training Loss')
plt.plot(epochs_range, validation_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# ## Dropout
#
# Another common method to reduce overfitting is called **dropout**, where we randomly drop neurons in our model during training. This forces the network to share information between weights, increasing its ability to generalize to new data. We can implement dropout in `tf.keras` by adding `tf.keras.layers.Dropout()` layers to our models.
#
# ```python
# tf.keras.layers.Dropout(rate)
# ```
# randomly sets a fraction `rate` of the dropout layer's input units to 0 at each update during training. The `rate` argument is a float between 0 and 1, that determines the fraction of neurons from the previous layer that should be turned off. For example,  `rate =0.5` will drop 50\% of the neurons.
#
# It's important to note that we should never apply dropout to the input layer of our network. Also, remember that during training we want to use dropout to prevent overfitting, but during inference we want to use all the neurons in the network. `tf.keras` is designed to care of this automatically, so it uses the dropout layers during training, but automatically ignores them during inference.

# %% [markdown]
# > **Exercise:** Add 3 dropout layers with a `rate=0.2` to our previous `model` and train it on Fashion-MNIST again. See if you can get a lower validation loss.

# %%
## Solution
rate = 0.2
model = tf.keras.Sequential([
        tf.keras.layers.Flatten(input_shape=(28,28,1)),
        tf.keras.layers.Dense(256, activation = 'relu'),
        tf.keras.layers.Dropout(rate),
        tf.keras.layers.Dense(128, activation = 'relu'),
        tf.keras.layers.Dropout(rate),    
        tf.keras.layers.Dense(64, activation = 'relu'),
        tf.keras.layers.Dropout(rate),
        tf.keras.layers.Dense(10, activation = 'softmax')
])

model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# Stop training when there is no improvement in the validation loss for 5 consecutive epochs
# early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=5)

history = model.fit(training_batches,
                    epochs = 100,
                    validation_data=validation_batches)
# Out:
# Epoch 1/100
# 750/750 [==============================] - 2s 3ms/step - loss: 0.6376 - accuracy: 0.7735 - val_loss: 0.4048 - val_accuracy: 0.8510
# Epoch 2/100
# 750/750 [==============================] - 2s 3ms/step - loss: 0.4481 - accuracy: 0.8381 - val_loss: 0.3738 - val_accuracy: 0.8586
# Epoch 3/100
# 750/750 [==============================] - 2s 3ms/step - loss: 0.4032 - accuracy: 0.8549 - val_loss: 0.3440 - val_accuracy: 0.8708
# Epoch 4/100
# 750/750 [==============================] - 2s 3ms/step - loss: 0.3799 - accuracy: 0.8644 - val_loss: 0.3777 - val_accuracy: 0.8585
# Epoch 5/100
# 750/750 [==============================] - 2s 2ms/step - loss: 0.3621 - accuracy: 0.8699 - val_loss: 0.3286 - val_accuracy: 0.8785
# Epoch 6/100
# 750/750 [==============================] - 2s 3ms/step - loss: 0.3486 - accuracy: 0.8739 - val_loss: 0.3157 - val_accuracy: 0.8843
# Epoch 7/100
# 750/750 [==============================] - 2s 3ms/step - loss: 0.3361 - accuracy: 0.8775 - val_loss: 0.3258 - val_accuracy: 0.8831
# Epoch 8/100
# 750/750 [==============================] - 2s 3ms/step - loss: 0.3271 - accuracy: 0.8802 - val_loss: 0.3243 - val_accuracy: 0.8801
# Epoch 9/100
# 750/750 [==============================] - 2s 3ms/step - loss: 0.3186 - accuracy: 0.8851 - val_loss: 0.3044 - val_accuracy: 0.8874
# Epoch 10/100
# 750/750 [==============================] - 2s 3ms/step - loss: 0.3083 - accuracy: 0.8878 - val_loss: 0.2991 - val_accuracy: 0.8913
# Epoch 11/100
# 750/750 [==============================] - 2s 3ms/step - loss: 0.3003 - accuracy: 0.8886 - val_loss: 0.2978 - val_accuracy: 0.8880
# Epoch 12/100
# 750/750 [==============================] - 2s 3ms/step - loss: 0.2992 - accuracy: 0.8913 - val_loss: 0.3021 - val_accuracy: 0.8888
# Epoch 13/100
# 750/750 [==============================] - 2s 3ms/step - loss: 0.2887 - accuracy: 0.8953 - val_loss: 0.3031 - val_accuracy: 0.8916
# Epoch 14/100
# 750/750 [==============================] - 2s 3ms/step - loss: 0.2851 - accuracy: 0.8951 - val_loss: 0.2968 - val_accuracy: 0.8904
# Epoch 15/100
# 750/750 [==============================] - 2s 3ms/step - loss: 0.2805 - accuracy: 0.8965 - val_loss: 0.2847 - val_accuracy: 0.8963
# Epoch 16/100
# 750/750 [==============================] - 2s 3ms/step - loss: 0.2723 - accuracy: 0.9001 - val_loss: 0.2873 - val_accuracy: 0.8951
# Epoch 17/100
# 750/750 [==============================] - 2s 3ms/step - loss: 0.2704 - accuracy: 0.8999 - val_loss: 0.2901 - val_accuracy: 0.8967
# Epoch 18/100
# 750/750 [==============================] - 2s 3ms/step - loss: 0.2665 - accuracy: 0.9016 - val_loss: 0.2905 - val_accuracy: 0.8932
# Epoch 19/100
# 750/750 [==============================] - 2s 3ms/step - loss: 0.2620 - accuracy: 0.9032 - val_loss: 0.3003 - val_accuracy: 0.8919
# Epoch 20/100
# 750/750 [==============================] - 2s 3ms/step - loss: 0.2571 - accuracy: 0.9045 - val_loss: 0.3118 - val_accuracy: 0.8952
# Epoch 21/100
# 750/750 [==============================] - 2s 3ms/step - loss: 0.2542 - accuracy: 0.9048 - val_loss: 0.2938 - val_accuracy: 0.8949
# Epoch 22/100
# 750/750 [==============================] - 2s 3ms/step - loss: 0.2530 - accuracy: 0.9058 - val_loss: 0.2848 - val_accuracy: 0.8975
# Epoch 23/100
# 750/750 [==============================] - 2s 3ms/step - loss: 0.2479 - accuracy: 0.9075 - val_loss: 0.2887 - val_accuracy: 0.8969
# Epoch 24/100
# 750/750 [==============================] - 2s 3ms/step - loss: 0.2455 - accuracy: 0.9097 - val_loss: 0.2850 - val_accuracy: 0.9007
# Epoch 25/100
# 750/750 [==============================] - 2s 3ms/step - loss: 0.2405 - accuracy: 0.9095 - val_loss: 0.2922 - val_accuracy: 0.8997
# Epoch 26/100
# 750/750 [==============================] - 2s 3ms/step - loss: 0.2386 - accuracy: 0.9115 - val_loss: 0.2895 - val_accuracy: 0.8986
# Epoch 27/100
# 750/750 [==============================] - 2s 3ms/step - loss: 0.2326 - accuracy: 0.9123 - val_loss: 0.2872 - val_accuracy: 0.9023
# Epoch 28/100
# 750/750 [==============================] - 2s 3ms/step - loss: 0.2332 - accuracy: 0.9136 - val_loss: 0.2847 - val_accuracy: 0.8997
# Epoch 29/100
# 750/750 [==============================] - 2s 3ms/step - loss: 0.2302 - accuracy: 0.9142 - val_loss: 0.2973 - val_accuracy: 0.8969
# Epoch 30/100
# 750/750 [==============================] - 2s 3ms/step - loss: 0.2269 - accuracy: 0.9150 - val_loss: 0.2891 - val_accuracy: 0.8997
# Epoch 31/100
# 750/750 [==============================] - 2s 3ms/step - loss: 0.2248 - accuracy: 0.9163 - val_loss: 0.3056 - val_accuracy: 0.8971
# Epoch 32/100
# 750/750 [==============================] - 2s 3ms/step - loss: 0.2244 - accuracy: 0.9163 - val_loss: 0.2916 - val_accuracy: 0.9004
# Epoch 33/100
# 750/750 [==============================] - 2s 3ms/step - loss: 0.2196 - accuracy: 0.9188 - val_loss: 0.2942 - val_accuracy: 0.8986
# Epoch 34/100
# 750/750 [==============================] - 2s 3ms/step - loss: 0.2197 - accuracy: 0.9178 - val_loss: 0.3022 - val_accuracy: 0.8986
# Epoch 35/100
# 750/750 [==============================] - 2s 3ms/step - loss: 0.2177 - accuracy: 0.9180 - val_loss: 0.2878 - val_accuracy: 0.8982
# Epoch 36/100
# 750/750 [==============================] - 2s 3ms/step - loss: 0.2171 - accuracy: 0.9197 - val_loss: 0.2971 - val_accuracy: 0.9003
# Epoch 37/100
# 750/750 [==============================] - 2s 3ms/step - loss: 0.2119 - accuracy: 0.9217 - val_loss: 0.2912 - val_accuracy: 0.9013
# Epoch 38/100
# 750/750 [==============================] - 2s 3ms/step - loss: 0.2117 - accuracy: 0.9207 - val_loss: 0.2852 - val_accuracy: 0.8983
# Epoch 39/100
# 750/750 [==============================] - 2s 3ms/step - loss: 0.2084 - accuracy: 0.9219 - val_loss: 0.3051 - val_accuracy: 0.8955
# Epoch 40/100
# 750/750 [==============================] - 2s 3ms/step - loss: 0.2051 - accuracy: 0.9230 - val_loss: 0.2850 - val_accuracy: 0.9036
# Epoch 41/100
# 750/750 [==============================] - 2s 3ms/step - loss: 0.2063 - accuracy: 0.9231 - val_loss: 0.2916 - val_accuracy: 0.8978
# Epoch 42/100
# 750/750 [==============================] - 2s 3ms/step - loss: 0.2012 - accuracy: 0.9236 - val_loss: 0.2960 - val_accuracy: 0.9016
# Epoch 43/100
# 750/750 [==============================] - 2s 3ms/step - loss: 0.2033 - accuracy: 0.9241 - val_loss: 0.3142 - val_accuracy: 0.8997
# Epoch 44/100
# 750/750 [==============================] - 2s 3ms/step - loss: 0.1999 - accuracy: 0.9250 - val_loss: 0.3112 - val_accuracy: 0.9008
# Epoch 45/100
# 750/750 [==============================] - 2s 3ms/step - loss: 0.1976 - accuracy: 0.9263 - val_loss: 0.3023 - val_accuracy: 0.9026
# Epoch 46/100
# 750/750 [==============================] - 2s 3ms/step - loss: 0.1934 - accuracy: 0.9280 - val_loss: 0.3023 - val_accuracy: 0.9023
# Epoch 47/100
# 750/750 [==============================] - 2s 3ms/step - loss: 0.1925 - accuracy: 0.9286 - val_loss: 0.3063 - val_accuracy: 0.9000
# Epoch 48/100
# 750/750 [==============================] - 2s 3ms/step - loss: 0.1918 - accuracy: 0.9283 - val_loss: 0.3179 - val_accuracy: 0.9005
# Epoch 49/100
# 750/750 [==============================] - 2s 3ms/step - loss: 0.1918 - accuracy: 0.9281 - val_loss: 0.2941 - val_accuracy: 0.9028
# Epoch 50/100
# 750/750 [==============================] - 2s 3ms/step - loss: 0.1887 - accuracy: 0.9306 - val_loss: 0.2997 - val_accuracy: 0.9022
# Epoch 51/100
# 750/750 [==============================] - 2s 3ms/step - loss: 0.1882 - accuracy: 0.9311 - val_loss: 0.3060 - val_accuracy: 0.9029
# Epoch 52/100
# 750/750 [==============================] - 2s 3ms/step - loss: 0.1887 - accuracy: 0.9293 - val_loss: 0.3231 - val_accuracy: 0.8992
# Epoch 53/100
# 750/750 [==============================] - 2s 3ms/step - loss: 0.1889 - accuracy: 0.9300 - val_loss: 0.2902 - val_accuracy: 0.9026
# Epoch 54/100
# 750/750 [==============================] - 2s 3ms/step - loss: 0.1826 - accuracy: 0.9315 - val_loss: 0.2997 - val_accuracy: 0.9028
# Epoch 55/100
# 750/750 [==============================] - 2s 3ms/step - loss: 0.1820 - accuracy: 0.9318 - val_loss: 0.3084 - val_accuracy: 0.8986
# Epoch 56/100
# 750/750 [==============================] - 2s 3ms/step - loss: 0.1807 - accuracy: 0.9327 - val_loss: 0.3056 - val_accuracy: 0.9020
# Epoch 57/100
# 750/750 [==============================] - 2s 3ms/step - loss: 0.1829 - accuracy: 0.9309 - val_loss: 0.3128 - val_accuracy: 0.9025
# Epoch 58/100
# 750/750 [==============================] - 2s 3ms/step - loss: 0.1805 - accuracy: 0.9338 - val_loss: 0.3148 - val_accuracy: 0.8994
# Epoch 59/100
# 750/750 [==============================] - 2s 3ms/step - loss: 0.1780 - accuracy: 0.9332 - val_loss: 0.3127 - val_accuracy: 0.9024
# Epoch 60/100
# 750/750 [==============================] - 2s 3ms/step - loss: 0.1791 - accuracy: 0.9334 - val_loss: 0.3207 - val_accuracy: 0.9018
# Epoch 61/100
# 750/750 [==============================] - 2s 3ms/step - loss: 0.1744 - accuracy: 0.9350 - val_loss: 0.3221 - val_accuracy: 0.8997
# Epoch 62/100
# 750/750 [==============================] - 2s 3ms/step - loss: 0.1748 - accuracy: 0.9345 - val_loss: 0.3205 - val_accuracy: 0.9024
# Epoch 63/100
# 750/750 [==============================] - 2s 3ms/step - loss: 0.1706 - accuracy: 0.9363 - val_loss: 0.3345 - val_accuracy: 0.8976
# Epoch 64/100
# 750/750 [==============================] - 2s 3ms/step - loss: 0.1740 - accuracy: 0.9344 - val_loss: 0.3269 - val_accuracy: 0.9023
# Epoch 65/100
# 750/750 [==============================] - 2s 3ms/step - loss: 0.1696 - accuracy: 0.9375 - val_loss: 0.3118 - val_accuracy: 0.9013
# Epoch 66/100
# 750/750 [==============================] - 2s 3ms/step - loss: 0.1724 - accuracy: 0.9359 - val_loss: 0.3134 - val_accuracy: 0.9051
# Epoch 67/100
# 750/750 [==============================] - 2s 3ms/step - loss: 0.1713 - accuracy: 0.9360 - val_loss: 0.3116 - val_accuracy: 0.9037
# Epoch 68/100
# 750/750 [==============================] - 2s 3ms/step - loss: 0.1638 - accuracy: 0.9385 - val_loss: 0.3180 - val_accuracy: 0.9060
# Epoch 69/100
# 750/750 [==============================] - 2s 3ms/step - loss: 0.1656 - accuracy: 0.9381 - val_loss: 0.3181 - val_accuracy: 0.9030
# Epoch 70/100
# 750/750 [==============================] - 2s 3ms/step - loss: 0.1659 - accuracy: 0.9385 - val_loss: 0.3168 - val_accuracy: 0.9020
# Epoch 71/100
# 750/750 [==============================] - 2s 3ms/step - loss: 0.1656 - accuracy: 0.9379 - val_loss: 0.3326 - val_accuracy: 0.9001
# Epoch 72/100
# 750/750 [==============================] - 2s 3ms/step - loss: 0.1630 - accuracy: 0.9391 - val_loss: 0.3323 - val_accuracy: 0.8980
# Epoch 73/100
# 750/750 [==============================] - 2s 2ms/step - loss: 0.1629 - accuracy: 0.9390 - val_loss: 0.3279 - val_accuracy: 0.8997
# Epoch 74/100
# 750/750 [==============================] - 2s 2ms/step - loss: 0.1607 - accuracy: 0.9405 - val_loss: 0.3266 - val_accuracy: 0.9016
# Epoch 75/100
# 750/750 [==============================] - 2s 3ms/step - loss: 0.1605 - accuracy: 0.9402 - val_loss: 0.3397 - val_accuracy: 0.8953
# Epoch 76/100
# 750/750 [==============================] - 2s 3ms/step - loss: 0.1564 - accuracy: 0.9413 - val_loss: 0.3286 - val_accuracy: 0.8975
# Epoch 77/100
# 750/750 [==============================] - 2s 3ms/step - loss: 0.1641 - accuracy: 0.9402 - val_loss: 0.3219 - val_accuracy: 0.9038
# Epoch 78/100
# 750/750 [==============================] - 2s 2ms/step - loss: 0.1561 - accuracy: 0.9425 - val_loss: 0.3364 - val_accuracy: 0.9016
# Epoch 79/100
# 750/750 [==============================] - 2s 3ms/step - loss: 0.1557 - accuracy: 0.9410 - val_loss: 0.3294 - val_accuracy: 0.8991
# Epoch 80/100
# 750/750 [==============================] - 2s 2ms/step - loss: 0.1571 - accuracy: 0.9411 - val_loss: 0.3254 - val_accuracy: 0.8987
# Epoch 81/100
# 750/750 [==============================] - 2s 3ms/step - loss: 0.1555 - accuracy: 0.9418 - val_loss: 0.3372 - val_accuracy: 0.8996
# Epoch 82/100
# 750/750 [==============================] - 2s 3ms/step - loss: 0.1529 - accuracy: 0.9436 - val_loss: 0.3364 - val_accuracy: 0.9021
# Epoch 83/100
# 750/750 [==============================] - 2s 3ms/step - loss: 0.1508 - accuracy: 0.9442 - val_loss: 0.3373 - val_accuracy: 0.9001
# Epoch 84/100
# 750/750 [==============================] - 2s 2ms/step - loss: 0.1525 - accuracy: 0.9438 - val_loss: 0.3380 - val_accuracy: 0.9027
# Epoch 85/100
# 750/750 [==============================] - 2s 3ms/step - loss: 0.1513 - accuracy: 0.9438 - val_loss: 0.3405 - val_accuracy: 0.9023
# Epoch 86/100
# 750/750 [==============================] - 2s 3ms/step - loss: 0.1514 - accuracy: 0.9441 - val_loss: 0.3449 - val_accuracy: 0.9018
# Epoch 87/100
# 750/750 [==============================] - 2s 3ms/step - loss: 0.1507 - accuracy: 0.9442 - val_loss: 0.3407 - val_accuracy: 0.9009
# Epoch 88/100
# 750/750 [==============================] - 2s 3ms/step - loss: 0.1511 - accuracy: 0.9442 - val_loss: 0.3471 - val_accuracy: 0.8997
# Epoch 89/100
# 750/750 [==============================] - 2s 3ms/step - loss: 0.1505 - accuracy: 0.9445 - val_loss: 0.3487 - val_accuracy: 0.9002
# Epoch 90/100
# 750/750 [==============================] - 2s 2ms/step - loss: 0.1485 - accuracy: 0.9446 - val_loss: 0.3349 - val_accuracy: 0.9015
# Epoch 91/100
# 750/750 [==============================] - 2s 2ms/step - loss: 0.1461 - accuracy: 0.9455 - val_loss: 0.3549 - val_accuracy: 0.8992
# Epoch 92/100
# 750/750 [==============================] - 2s 2ms/step - loss: 0.1487 - accuracy: 0.9456 - val_loss: 0.3597 - val_accuracy: 0.9013
# Epoch 93/100
# 750/750 [==============================] - 2s 2ms/step - loss: 0.1454 - accuracy: 0.9461 - val_loss: 0.3487 - val_accuracy: 0.9028
# Epoch 94/100
# 750/750 [==============================] - 2s 2ms/step - loss: 0.1445 - accuracy: 0.9467 - val_loss: 0.3522 - val_accuracy: 0.9007
# Epoch 95/100
# 750/750 [==============================] - 2s 3ms/step - loss: 0.1429 - accuracy: 0.9461 - val_loss: 0.3572 - val_accuracy: 0.8992
# Epoch 96/100
# 750/750 [==============================] - 2s 2ms/step - loss: 0.1458 - accuracy: 0.9471 - val_loss: 0.3400 - val_accuracy: 0.9028
# Epoch 97/100
# 750/750 [==============================] - 2s 2ms/step - loss: 0.1431 - accuracy: 0.9470 - val_loss: 0.3285 - val_accuracy: 0.9051
# Epoch 98/100
# 750/750 [==============================] - 2s 2ms/step - loss: 0.1414 - accuracy: 0.9487 - val_loss: 0.3498 - val_accuracy: 0.9013
# Epoch 99/100
# 750/750 [==============================] - 2s 2ms/step - loss: 0.1363 - accuracy: 0.9491 - val_loss: 0.3704 - val_accuracy: 0.9022
# Epoch 100/100
# 750/750 [==============================] - 2s 2ms/step - loss: 0.1411 - accuracy: 0.9490 - val_loss: 0.3522 - val_accuracy: 0.9011

# %%
training_accuracy = history.history['accuracy']
validation_accuracy = history.history['val_accuracy']

training_loss = history.history['loss']
validation_loss = history.history['val_loss']

epochs_range=range(len(training_accuracy))

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, training_accuracy, label='Training Accuracy')
plt.plot(epochs_range, validation_accuracy, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, training_loss, label='Training Loss')
plt.plot(epochs_range, validation_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# ## Inference
#
# Now that the model is trained, we can use it to perform inference. Here we are going to perform inference on 30 images and print the labels in green if our model's prediction matches the true label. On the other hand, if our model's prediction doesn't match the true label, we print the label in red.

# %%
for image_batch, label_batch in testing_batches.take(1):
    ps = model.predict(image_batch)
    images = image_batch.numpy().squeeze()
    labels = label_batch.numpy()


plt.figure(figsize=(10,15))

for n in range(30):
    plt.subplot(6,5,n+1)
    plt.imshow(images[n], cmap = plt.cm.binary)
    color = 'green' if np.argmax(ps[n]) == labels[n] else 'red'
    plt.title(class_names[np.argmax(ps[n])], color=color)
    plt.axis('off')

# %% [markdown]
# ## Next Up!
#
# In the next lesson, we'll see how to save our trained models. In general, you won't want to train a model every time you need it. Instead, you'll train once, save it, then load the model when you want to train more or use it for inference.
